# %%
import argparse
import logging
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import numpy as np

# %%
client_id = "087c43da5f8f4701af2195902f821d91"
client_secret = "4f1fae6fda2b4304a72390aeeca957fc"
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
# Run the above cell and this cell prior to opening the webpage, will need the access token 
# once access token is generated, copy and paste into js file where designated.

spotipy.oauth2.SpotifyClientCredentials.get_access_token(client_credentials_manager)
# Out:
# 'BQC4zj6A8y6RMK_UDZAxO7b6lhywDBPSgisQmygGw9a5OiwPjvhg12V6V04iJ1Bu_d_Aqoc1b47HnujU5dU'

# %%
response1 = sp.playlist_tracks('spotify:playlist:37i9dQZF1DWUQuMV5yVzhv')
number_of_artist = np.arange(0,50)
num_a = np.arange(0,50)
number_of_tracks = [0,1,2,3,4]
number_of_songs = [0,1,2,3,4]
uri_list = []
track_names = []
track_uris = []
track_ids = []
track_urls = []
artist_names = []
artist2_names=[]
test_dict = {}

# %%
for number in number_of_artist:
    uri = response1['items'][number]['track']['album']['artists'][0]['uri']
    uri_list.append(uri)

# %%
for number in number_of_artist:
    a_name = response1['items'][number]['track']['album']['artists'][0]['name']
    artist_names.append(a_name)

# %%
test_dict['Artists'] = artist_names[0:25]
'spotify:track:1je8gnq0123tgh'

# %%
for uri in uri_list:
    for number in number_of_tracks:
        try:
            response = sp.artist_top_tracks(uri)
            t_name = response['tracks'][number]['name']
            track_names.append(t_name)
            t_uri = response['tracks'][number]['uri']
            t_id = t_uri[14:36]
            track_ids.append(t_id)
            track_uris.append(t_uri)
            t_url = response['tracks'][number]['external_urls']['spotify']
            t_url2 = t_url[:25] + 'embed/' + t_url[25:]
            track_urls.append(t_url2)
        except:
            print('Necessary Data Missing From Track Response')

# %%
artist_info_dict = {
    'Artists':[
        artist_names[0],
        artist_names[1],
        artist_names[2],
        artist_names[3],
        artist_names[4],
        artist_names[5],
        artist_names[6],
        artist_names[7],
        artist_names[8],
        artist_names[9],
        artist_names[10],
        artist_names[11],
        artist_names[12],
        artist_names[13],
        artist_names[14],
        artist_names[15],
        artist_names[16],
        artist_names[17],
        artist_names[18],
        artist_names[19],
        artist_names[20],
        artist_names[21],
        artist_names[22],
        artist_names[23],
        artist_names[24],
        artist_names[25],
        artist_names[26],
        artist_names[27],
        artist_names[28],
        artist_names[29],
        artist_names[30],
        artist_names[31],
        artist_names[32],
        artist_names[33],
        artist_names[34],
        artist_names[35],
        artist_names[36],
        artist_names[37],
        artist_names[38],
        artist_names[39],
        artist_names[40],
        artist_names[41],
        artist_names[42],
        artist_names[43],
        artist_names[44],
        artist_names[45],
        artist_names[46],
        artist_names[47],
        artist_names[48],
        artist_names[49]
        ],
    'Metadata':[
        {
        'Artist':artist_names[0],
        'Tracks':track_names[0:5],
        'Track_URI':track_uris[0:5],
        'Track_ID':track_ids[0:5],
        'Track_Play_URL':track_urls[0:5]
        },
        {
        'Artist':artist_names[1],
        'Tracks':track_names[5:10],
        'Track_URI':track_uris[5:10],
        'Track_ID':track_ids[5:10],
        'Track_Play_URL':track_urls[5:10]
        },
        {
        'Artist':artist_names[2],
        'Tracks':track_names[10:15],
        'Track_URI':track_uris[10:15],
        'Track_ID':track_ids[10:15],
        'Track_Play_URL':track_urls[10:15]
        },
        {
        'Artist':artist_names[3],
        'Tracks':track_names[15:20],
        'Track_URI':track_uris[15:20],
        'Track_ID':track_ids[15:20],
        'Track_Play_URL':track_urls[15:20]
        },
        {
        'Artist':artist_names[4],
        'Tracks':track_names[20:25],
        'Track_URI':track_uris[20:25],
        'Track_ID':track_ids[20:25],
        'Track_Play_URL':track_urls[20:25]
        },
        {
        'Artist':artist_names[5],
        'Tracks':track_names[25:30],
        'Track_URI':track_uris[25:30],
        'Track_ID':track_ids[25:30],
        'Track_Play_URL':track_urls[25:30]
        },
        {
        'Artist':artist_names[6],
        'Tracks':track_names[30:35],
        'Track_URI':track_uris[30:35],
        'Track_ID':track_ids[30:35],
        'Track_Play_URL':track_urls[30:35]
        },
        {
        'Artist':artist_names[7],
        'Tracks':track_names[35:40],
        'Track_URI':track_uris[35:40],
        'Track_ID':track_ids[35:40],
        'Track_Play_URL':track_urls[35:40]
        },
        {
        'Artist':artist_names[8],
        'Tracks':track_names[40:45],
        'Track_URI':track_uris[40:45],
        'Track_ID':track_ids[40:45],
        'Track_Play_URL':track_urls[40:45]
        },
        {
        'Artist':artist_names[9],
        'Tracks':track_names[45:50],
        'Track_URI':track_uris[45:50],
        'Track_ID':track_ids[45:50],
        'Track_Play_URL':track_urls[45:50]
        },
        {
        'Artist':artist_names[10],
        'Tracks':track_names[50:55],
        'Track_URI':track_uris[50:55],
        'Track_ID':track_ids[50:55],
        'Track_Play_URL':track_urls[50:55]
        },
        {
        'Artist':artist_names[11],
        'Tracks':track_names[55:60],
        'Track_URI':track_uris[55:60],
        'Track_ID':track_ids[55:60],
        'Track_Play_URL':track_urls[55:60]
        },
        {
        'Artist':artist_names[12],
        'Tracks':track_names[60:65],
        'Track_URI':track_uris[60:65],
        'Track_ID':track_ids[60:65],
        'Track_Play_URL':track_urls[60:65]
        },
        {
        'Artist':artist_names[13],
        'Tracks':track_names[65:70],
        'Track_URI':track_uris[65:70],
        'Track_ID':track_ids[65:70],
        'Track_Play_URL':track_urls[65:70]
        },
        {
        'Artist':artist_names[14],
        'Tracks':track_names[70:75],
        'Track_URI':track_uris[70:75],
        'Track_ID':track_ids[70:75],
        'Track_Play_URL':track_urls[70:75]
        },
        {
        'Artist':artist_names[15],
        'Tracks':track_names[75:80],
        'Track_URI':track_uris[75:80],
        'Track_ID':track_ids[75:80],
        'Track_Play_URL':track_urls[75:80]
        },
        {
        'Artist':artist_names[16],
        'Tracks':track_names[80:85],
        'Track_URI':track_uris[80:85],
        'Track_ID':track_ids[80:85],
        'Track_Play_URL':track_urls[80:85]
        },
        {
        'Artist':artist_names[17],
        'Tracks':track_names[85:90],
        'Track_URI':track_uris[85:90],
        'Track_ID':track_ids[85:90],
        'Track_Play_URL':track_urls[85:90]
        },
        {
        'Artist':artist_names[18],
        'Tracks':track_names[90:95],
        'Track_URI':track_uris[90:95],
        'Track_ID':track_ids[90:95],
        'Track_Play_URL':track_urls[90:95]
        },
        {
        'Artist':artist_names[19],
        'Tracks':track_names[95:100],
        'Track_URI':track_uris[95:100],
        'Track_ID':track_ids[95:100],
        'Track_Play_URL':track_urls[95:100]
        },
        {
        'Artist':artist_names[20],
        'Tracks':track_names[100:105],
        'Track_URI':track_uris[100:105],
        'Track_ID':track_ids[100:105],
        'Track_Play_URL':track_urls[100:105]
        },
        {
        'Artist':artist_names[21],
        'Tracks':track_names[105:110],
        'Track_URI':track_uris[105:110],
        'Track_ID':track_ids[105:110],
        'Track_Play_URL':track_urls[105:110]
        },
        {
        'Artist':artist_names[22],
        'Tracks':track_names[110:115],
        'Track_URI':track_uris[110:115],
        'Track_ID':track_ids[110:115],
        'Track_Play_URL':track_urls[110:115]
        },
        {
        'Artist':artist_names[23],
        'Tracks':track_names[115:120],
        'Track_URI':track_uris[115:120],
        'Track_ID':track_ids[115:120],
        'Track_Play_URL':track_urls[115:120]
        },
        {
        'Artist':artist_names[24],
        'Tracks':track_names[120:125],
        'Track_URI':track_uris[120:125],
        'Track_ID':track_ids[120:125],
        'Track_Play_URL':track_urls[120:125]
        },
        {
        'Artist':artist_names[25],
        'Tracks':track_names[125:130],
        'Track_URI':track_uris[125:130],
        'Track_ID':track_ids[125:130],
        'Track_Play_URL':track_urls[125:130]
        },
        {
        'Artist':artist_names[26],
        'Tracks':track_names[130:135],
        'Track_URI':track_uris[130:135],
        'Track_ID':track_ids[130:135],
        'Track_Play_URL':track_urls[130:135]
        },
        {
        'Artist':artist_names[27],
        'Tracks':track_names[135:140],
        'Track_URI':track_uris[135:140],
        'Track_ID':track_ids[135:140],
        'Track_Play_URL':track_urls[135:140]
        },
        {
        'Artist':artist_names[28],
        'Tracks':track_names[140:145],
        'Track_URI':track_uris[140:145],
        'Track_ID':track_ids[140:145],
        'Track_Play_URL':track_urls[140:145]
        },
        {
        'Artist':artist_names[29],
        'Tracks':track_names[145:150],
        'Track_URI':track_uris[145:150],
        'Track_ID':track_ids[145:150],
        'Track_Play_URL':track_urls[145:150]
        },
        {
        'Artist':artist_names[30],
        'Tracks':track_names[150:155],
        'Track_URI':track_uris[150:155],
        'Track_ID':track_ids[150:155],
        'Track_Play_URL':track_urls[150:155]
        },
        {
        'Artist':artist_names[31],
        'Tracks':track_names[155:160],
        'Track_URI':track_uris[155:160],
        'Track_ID':track_ids[155:160],
        'Track_Play_URL':track_urls[155:160]
        },
        {
        'Artist':artist_names[32],
        'Tracks':track_names[160:165],
        'Track_URI':track_uris[160:165],
        'Track_ID':track_ids[160:165],
        'Track_Play_URL':track_urls[160:165]
        },
        {
        'Artist':artist_names[33],
        'Tracks':track_names[165:170],
        'Track_URI':track_uris[165:170],
        'Track_ID':track_ids[165:170],
        'Track_Play_URL':track_urls[165:170]
        },
        {
        'Artist':artist_names[34],
        'Tracks':track_names[170:175],
        'Track_URI':track_uris[170:175],
        'Track_ID':track_ids[170:175],
        'Track_Play_URL':track_urls[170:175]
        },
        {
        'Artist':artist_names[35],
        'Tracks':track_names[175:180],
        'Track_URI':track_uris[175:180],
        'Track_ID':track_ids[175:180],
        'Track_Play_URL':track_urls[175:180]
        },
        {
        'Artist':artist_names[36],
        'Tracks':track_names[180:185],
        'Track_URI':track_uris[180:185],
        'Track_ID':track_ids[180:185],
        'Track_Play_URL':track_urls[180:185]
        },
        {
        'Artist':artist_names[37],
        'Tracks':track_names[185:190],
        'Track_URI':track_uris[185:190],
        'Track_ID':track_ids[185:190],
        'Track_Play_URL':track_urls[185:190]
        },
        {
        'Artist':artist_names[38],
        'Tracks':track_names[190:195],
        'Track_URI':track_uris[190:195],
        'Track_ID':track_ids[190:195],
        'Track_Play_URL':track_urls[190:195]
        },
        {
        'Artist':artist_names[39],
        'Tracks':track_names[195:200],
        'Track_URI':track_uris[195:200],
        'Track_ID':track_ids[195:200],
        'Track_Play_URL':track_urls[195:200]
        },
        {
        'Artist':artist_names[40],
        'Tracks':track_names[200:205],
        'Track_URI':track_uris[200:205],
        'Track_ID':track_ids[200:205],
        'Track_Play_URL':track_urls[200:205]
        },
        {
        'Artist':artist_names[41],
        'Tracks':track_names[205:210],
        'Track_URI':track_uris[205:210],
        'Track_ID':track_ids[205:210],
        'Track_Play_URL':track_urls[205:210]
        },
        {
        'Artist':artist_names[42],
        'Tracks':track_names[210:215],
        'Track_URI':track_uris[210:215],
        'Track_ID':track_ids[210:215],
        'Track_Play_URL':track_urls[210:215]
        },
        {
        'Artist':artist_names[43],
        'Tracks':track_names[215:220],
        'Track_URI':track_uris[215:220],
        'Track_ID':track_ids[215:220],
        'Track_Play_URL':track_urls[215:220]
        },
        {
        'Artist':artist_names[44],
        'Tracks':track_names[220:225],
        'Track_URI':track_uris[220:225],
        'Track_ID':track_ids[220:225],
        'Track_Play_URL':track_urls[220:225]
        },
        {
        'Artist':artist_names[45],
        'Tracks':track_names[225:230],
        'Track_URI':track_uris[225:230],
        'Track_ID':track_ids[225:230],
        'Track_Play_URL':track_urls[225:230]
        },
        {
        'Artist':artist_names[46],
        'Tracks':track_names[230:235],
        'Track_URI':track_uris[230:235],
        'Track_ID':track_ids[230:235],
        'Track_Play_URL':track_urls[230:235]
        },
        {
        'Artist':artist_names[47],
        'Tracks':track_names[235:240],
        'Track_URI':track_uris[235:240],
        'Track_ID':track_ids[235:240],
        'Track_Play_URL':track_urls[235:240]
        },
        {
        'Artist':artist_names[48],
        'Tracks':track_names[240:245],
        'Track_URI':track_uris[240:245],
        'Track_ID':track_ids[240:245],
        'Track_Play_URL':track_urls[240:245]
        },
        {
        'Artist':artist_names[49],
        'Tracks':track_names[245:250],
        'Track_URI':track_uris[245:250],
        'Track_ID':track_ids[245:250],
        'Track_Play_URL':track_urls[245:250]
        }
        ]
}

# %%
from pymongo import MongoClient
from bson.json_util import dumps
client = MongoClient('localhost', 27017)
db = client['spotify_db']
artist_info = db['artist_info']

# %%
artist_info.insert_one(artist_info_dict)

# %%
cursor = artist_info.find()
cursor_list = list(cursor)
json_data = dumps(cursor_list)

# %%
with open('artist_data.json','w') as file:
    file.write(json_data)
